# %%
fs2au = 41.341374575751
cminv2au = 4.55633*1e-6
eV2au = 0.036749405469679
K2au = 0.00000316678
Kb = 8.617333262*1e-5*eV2au/K2au        # Kb = 8.617333262 x 10^-5 eV/K
T = 300*K2au                            # Temperature in au
β = 1/(Kb*T)
print(β)
# Out:
# 1052.5810303081116

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
from IPython.display import display
from IPython import display

# %%
@interact_manual()
def plot(N = 10):
    plt.plot(np.arange(N),np.sin(np.arange(N)))
# Out:
# interactive(children=(IntSlider(value=10, description='N', max=30, min=-10), Button(description='Run Interact'…

# %%
from numba import jit 

@jit(nopython=True)
def dict_test(x):
    b = 0
    for i in range(x):
        for j in range(x):
            for k in range(x):
                b[(i,j,k)] = i+j+k
    return b

dict_test(10)

# %%
b = {}
x = 1000
for i in range(x):
    for j in range(x):
        for k in range(x):
            b[(i,j,k)] = i+j+k
print()
# Out:
# 1498500000001
